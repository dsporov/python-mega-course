# %%
import os
os.listdir('.')
# Out:
# ['.ipynb_checkpoints',
#  'supermarkets-commas.txt',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.csv',
#  'supermarkets.json',
#  'supermarkets.xlsx',
#  'Untitled.ipynb']

# %% [markdown]
# # import pandas
# df1 = pandas.read_csv('supermarkets.csv')
# df1

# %%
import pandas
df1 = pandas.read_json('supermarkets.json')
df1
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
import pandas
df1 = pandas.read_excel('supermarkets.xlsx',  sheet_name=0)
df1
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df2 = pandas.read_csv('supermarkets-semi-colons.txt', sep=';')
#df2 = pandas.read_csv('supermarkets-semi-colons.txt', sep=';', header=None)
df2 = df2.set_index("ID")
# if df2.set_index("ID", inplace=True) then df2 will be modified rather that returning a modified copy
# , drop = false => not delete initial column that was made as an index
df2

df2 = df2.set_index("Address")
df2.loc["735 Dolores St" : "332 Hill St", "City" : "Name"]

list(df2.loc[:, "Country"])
# Out:
# ['USA', 'USA', 'USA', 'USA', 'USA', 'USA']

# %%
df2 = pandas.read_csv('supermarkets-semi-colons.txt', sep=';')
df2.iloc[:, 3]
#df2.drop(df2.columns[0:3], 1) #delete columns 0-3

#df2.drop('State', 1) # delete col
#df2.drop(1, 0) # delete row index 1
#df2.drop(df2.index[0:3], 0) #delete rows 0-3
# Out:
#               State Country          Name  Employees
# 0          CA 94114     USA       Madeira          8
# 1          CA 94119     USA   Bready Shop         15
# 2  California 94114     USA   Super River         25
# 3          CA 94114     USA    Ben's Shop         10
# 4        California     USA       Sanchez         12
# 5          CA 94114     USA    Richvalley         20

# %%
df2 = pandas.read_csv('supermarkets-semi-colons.txt', sep=';')
#df2['Continent'] = ['North America'] @gives an error
df2.shape # data frame size
df2.shape[0] *['North America'] # numRows times 'North America']
df2['Continent'] = df2.shape[0] *['North America']
#df2['Continent'] = [['North America'], ['North America'], ['North America'],['North America'], ['North America'], ['North America']] 
#6 * ['North America']
df2['Continent'] = df2.shape[0] *['North America']
df2
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees      Continent
# 0          8  North America
# 1         15  North America
# 2         25  North America
# 3         10  North America
# 4         12  North America
# 5         20  North America

# %%
df2 = pandas.read_csv('supermarkets-semi-colons.txt', sep=';')
df2['Continent'] = df2['Country'] + ',' + ' North America'
df2
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees           Continent
# 0          8  USA, North America
# 1         15  USA, North America
# 2         25  USA, North America
# 3         10  USA, North America
# 4         12  USA, North America
# 5         20  USA, North America

# %%
df2 = pandas.read_csv('supermarkets-semi-colons.txt', sep=';')
df2 = df2.T # transpose
# modify exixting row if pass existing index to df2[idx]
df2[7] = [7, "My address", "My city", "My State", "My country", "My name", 9]
df2 = df2.T
df2
# Out:
#   ID          Address           City             State     Country  \
# 0  1     3666 21st St  San Francisco          CA 94114         USA
# 1  2   735 Dolores St  San Francisco          CA 94119         USA
# 2  3      332 Hill St  San Francisco  California 94114         USA
# 3  4     3995 23rd St  San Francisco          CA 94114         USA
# 4  5  1056 Sanchez St  San Francisco        California         USA
# 5  6  551 Alvarado St  San Francisco          CA 94114         USA
# 7  7       My address        My city          My State  My country
#
#            Name Employees
# 0       Madeira         8
# 1   Bready Shop        15
# 2   Super River        25
# 3    Ben's Shop        10
# 4       Sanchez        12
# 5    Richvalley        20
# 7       My name         9

# %%
from geopy.geocoders import ArcGIS
nom = ArcGIS()
df = pandas.read_csv('supermarkets.csv')
df['Address'] = df['Address'] + ', ' + df['City'] + ', ' + df['State'] + ', ' + df['Country']
df['Coordinates'] = df['Address'].apply(nom.geocode)
df.Coordinates[0]
# Out:
# Location((37.7564444932, -122.429353144, 0.0))

# %%
df['Latitude'] = df.Coordinates.apply(lambda x: x.latitude if x != None else None)
df['Longitude'] = df.Coordinates.apply(lambda x: x.longitude if x != None else None)
df
# Out:
#    ID                                            Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, USA  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California, USA  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                          Coordinates   Latitude   Longitude
# ...
